# %%
import pandas as pd
import os
from datetime import datetime

# %% [markdown]
# be sure to include to include info from the meta data

# %%
csvFile = "session_one/mindMonitor_2021-02-10--09-18-15.csv"
pd.read_csv(csvFile)
# Out:
#                    TimeStamp  Delta_TP9  Delta_AF7  Delta_AF8  Delta_TP10  \
# 0    2021-02-10 09:18:16.055   0.865653  -0.327438   0.140971    0.401411
# 1    2021-02-10 09:18:17.005        NaN        NaN        NaN         NaN
# 2    2021-02-10 09:18:17.069   0.824242   0.544351   0.732053    0.419032
# 3    2021-02-10 09:18:17.695        NaN        NaN        NaN         NaN
# 4    2021-02-10 09:18:18.055   0.975602   0.897456   0.597753    0.718995
# ..                       ...        ...        ...        ...         ...
# 968  2021-02-10 09:30:08.110   0.148766   0.307990   1.113539    0.161204
# 969  2021-02-10 09:30:09.117   0.490817  -0.018484   0.624523    0.197961
# 970  2021-02-10 09:30:10.109   1.460793   0.483148   0.726434    0.845810
# 971  2021-02-10 09:30:11.109   1.513219   0.914390   0.714909    0.800659
# 972  2021-02-10 09:30:12.122   0.674520   0.495715   0.694395    0.749038
#
#      Theta_TP9  Theta_AF7  Theta_AF8  Theta_TP10  Alpha_TP9  ...  \
# ...
